# %% [markdown]
# **Task 6 — Deployment & CI (Summary)**
# - Objective: Containerize the trained model, serve it with FastAPI, and enforce code quality via CI.
# - Implementation: `src/api/main.py` loads the best model from MLflow or local `models/` and exposes `/predict`, `/health`, and `/model-info` endpoints.
# - Validation: Request/response schemas implemented in `src/api/pydantic_models.py`.
# - Containerization: `Dockerfile` and `docker-compose.yml` run the API, an MLflow server, and the Streamlit dashboard (ports 8000/5000/8501).
# - CI: `.github/workflows/ci.yml` runs `flake8` and `pytest` on pushes to `main` (pipeline fails if lint or tests fail).
# - Deployment: Streamlit dashboard deployed (Render) and MLflow tracking server configured; services wired via docker-compose.
# - Notes: Inputs are validated and preprocessed (WoE + preprocessor); predictions return risk probability, category, credit score, and loan recommendations.
